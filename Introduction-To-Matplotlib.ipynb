# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4])

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %%
plt.plot(x, y)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# %%
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
fig, ax  = plt.subplots(figsize=(10,10))
ax.plot(x, y)
ax.set(title="Chocolaty Kinza Amjad", xlabel="x-axis", ylabel="y-axis")
fig.savefig('choco-kinzi.png')

# %%
x = [100, 200, 300, 500, 1000]
y = [1000, 5000, 7000, 77000, 99000]
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(x, y)
ax.set(title="Chocolaty Kinza Amjad", xlabel="x-axis", ylabel="y-axis")
fig.savefig('chocobar-kinza.png')

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([0.0000000e+00, 2.0000002e-06, 4.0000004e-06, ..., 1.9999996e+01,
#        1.9999998e+01, 2.0000000e+01])

# %%
x[:100]
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
ax.plot(x, x ** 2)

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
fig, ax = plt.subplots()
ax.plot(x, np.sin(x))

# %%
plt.pie(x)
plt.show()

# %%
x = [100, 200, 300, 500]
myLabels = ["Kinza Amjad", "Rabia Amjad", "Ramsha Naseer", "Chocolaty Kinza Amjad"]
plt.pie(x, labels= myLabels)
plt.show()

# %%
nut_butter_prices = {"Armond Butter": 10, "Peanut Butter": 8, "Cachew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Stor", ylabel="Price ($)");

# %%
x = np.random.randn(100)
x
# Out:
# array([-5.61359679e-01,  8.90100416e-01,  6.53475119e-01, -1.81144215e+00,
#         1.40356217e+00,  6.14882202e-01, -1.14370734e+00,  1.81024383e+00,
#         1.78079911e-01, -1.06546668e+00, -4.09019630e-01,  1.87117196e-01,
#        -5.19752224e-01, -6.33506145e-01,  1.13378568e+00,  6.84199138e-01,
#         7.44215661e-01, -9.95832590e-01,  2.58880923e+00,  3.66264402e-01,
#         4.45889012e-01, -1.08405502e+00, -4.74212022e-01,  3.26211132e-02,
#         6.30073457e-02, -1.30045271e+00,  1.01368601e+00,  5.39551834e-01,
#        -1.75591786e+00,  9.40211496e-01, -1.45456774e+00, -1.18452034e+00,
#        -1.67621865e+00, -1.31766978e-01,  5.88648734e-02, -7.55501841e-01,
#         5.62596007e-01, -3.14013534e-01,  6.21121553e-01, -1.04154105e+00,
#         1.44986001e+00, -2.30313465e-01, -4.31248125e-01,  2.44264804e+00,
#         1.43140141e-01, -1.15523275e+00, -5.23866966e-02, -5.83567190e-01,
#        -8.68469157e-01, -2.09131607e+00,  5.79732495e-01, -9.98295239e-01,
#        -1.85685522e+00, -2.42684547e-01, -4.02236831e-01, -1.04469958e+00,
#         2.31132562e-01,  1.64573275e-03,  2.28263228e-01,  2.46745603e+00,
#        -1.90121538e-02,  2.15592103e+00,  3.24589396e-01, -9.08660808e-01,
#         5.85448146e-01,  6.32695218e-01, -4.97887165e-01,  1.30283741e-01,
#        -1.75851234e+00,  1.56938994e-01, -3.91161445e-01,  1.26865767e+00,
#         2.12664762e-01,  4.38221138e-01, -1.65146694e+00,  4.97168323e-01,
#         3.38104872e-01, -1.07307321e+00, -3.95411691e-01, -2.84902618e-01,
#        -1.45317030e-01, -1.36614605e-01,  3.50277721e-01,  5.97784996e-01,
#         5.61048523e-01,  8.52724469e-01,  7.82109797e-01, -3.68539105e-01,
#         5.03015522e-01, -7.51738165e-01, -2.02268402e-01, -4.60729290e-02,
#        -7.77700153e-01,  3.70368102e-02, -2.69639491e-01, -1.09550559e-01,
#        -1.02862893e+00,  7.59395896e-01, -2.37783883e-01, -6.62809774e-01])

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  7.,  20.,  74., 204., 285., 234., 132.,  37.,   5.,   2.]),
#  array([-3.53542598, -2.77889275, -2.02235952, -1.26582629, -0.50929306,
#          0.24724017,  1.00377339,  1.76030662,  2.51683985,  3.27337308,
#          4.02990631]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  1.,   9.,  39., 156., 278., 275., 170.,  55.,  13.,   4.]),
#  array([-3.69200794, -2.96177792, -2.2315479 , -1.50131787, -0.77108785,
#         -0.04085783,  0.68937219,  1.41960222,  2.14983224,  2.88006226,
#          3.61029229]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2,
                                            ncols = 2,
                                            figsize = (10, 5))
ax1.plot(x, x / 2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices. values())
ax4.hist(np.random.randn(10000))
# Out:
# (array([  18.,  123.,  632., 1701., 2817., 2672., 1508.,  454.,   68.,
#            7.]),
#  array([-3.72761952, -2.96541202, -2.20320451, -1.440997  , -0.6787895 ,
#          0.08341801,  0.84562552,  1.60783302,  2.37004053,  3.13224803,
#          3.89445554]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(nrows = 2,
                      ncols = 2,
                      figsize = (10, 5))
ax[0, 0].plot(x, x / 2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000));

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index= pd.date_range("7/15/2021", periods=1000))

# %%
ts
# Out:
# 2021-07-15    0.448099
# 2021-07-16   -0.195626
# 2021-07-17   -0.769336
# 2021-07-18   -1.294359
# 2021-07-19   -0.156012
#                 ...
# 2024-04-05    0.442463
# 2024-04-06    1.822142
# 2024-04-07   -0.827165
# 2024-04-08    0.276007
# 2024-04-09   -0.346129
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2021-07-15    0.448099
# 2021-07-16    0.252473
# 2021-07-17   -0.516863
# 2021-07-18   -1.811222
# 2021-07-19   -1.967234
#                 ...
# 2024-04-05    0.477991
# 2024-04-06    2.300133
# 2024-04-07    1.472969
# 2024-04-08    1.748976
# 2024-04-09    1.402846
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
ts = pd.Series(np.random.randn(2000), index= pd.date_range("15/7/2021", periods = 2000))

# %%
ts
# Out:
# 2021-07-15    0.097221
# 2021-07-16   -0.188806
# 2021-07-17   -0.072403
# 2021-07-18   -0.221317
# 2021-07-19    1.259615
#                 ...
# 2026-12-31   -1.693267
# 2027-01-01   -0.918771
# 2027-01-02    1.206740
# 2027-01-03   -1.424175
# 2027-01-04   -1.299387
# Freq: D, Length: 2000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2021-07-15     0.097221
# 2021-07-16    -0.091585
# 2021-07-17    -0.163988
# 2021-07-18    -0.385305
# 2021-07-19     0.874310
#                 ...
# 2026-12-31   -44.653540
# 2027-01-01   -45.572311
# 2027-01-02   -44.365571
# 2027-01-03   -45.789745
# 2027-01-04   -47.089132
# Freq: D, Length: 2000, dtype: float64

# %%
ts.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[/$, /,/.]', '')

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("15/7/2021", periods=len(cars_sales))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-5a9098958d7d> in <module>
# ----> 1 car_sales["Sale Date"] = pd.date_range("15/7/2021", periods=len(cars_sales))
#
# NameError: name 'cars_sales' is not defined

# %%
car_sales["Sale Date"] = pd.date_range("15/7/2021", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sale Price  Total Sales  \
# 0  Toyota  White         150043      4   4000 2021-07-15         4000
# 1   Honda    Red          87899      4   5000 2021-07-16         9000
# 2  Toyota   Blue          32549      3   7000 2021-07-17        16000
# 3     BMW  Black          11179      5  22000 2021-07-18        38000
# 4  Nissan  White         213095      4   3500 2021-07-19        41500
# 5  Toyota  Green          99213      4   4500 2021-07-20        46000
# 6   Honda   Blue          45698      4   7500 2021-07-21        53500
# 7   Honda   Blue          54738      4   7000 2021-07-22        60500
# 8  Toyota  White          60000      4   6250 2021-07-23        66750
# 9  Nissan  White          31600      4   9700 2021-07-24        76450
#
#    Sale Date
# 0 2021-07-15
# 1 2021-07-16
# 2 2021-07-17
# 3 2021-07-18
# 4 2021-07-19
# 5 2021-07-20
# 6 2021-07-21
# 7 2021-07-22
# 8 2021-07-23
# 9 2021-07-24

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sale Price  Total Sales
# 0  Toyota  White         150043      4   4000 2021-07-15         4000
# 1   Honda    Red          87899      4   5000 2021-07-16         9000
# 2  Toyota   Blue          32549      3   7000 2021-07-17        16000
# 3     BMW  Black          11179      5  22000 2021-07-18        38000
# 4  Nissan  White         213095      4   3500 2021-07-19        41500
# 5  Toyota  Green          99213      4   4500 2021-07-20        46000
# 6   Honda   Blue          45698      4   7500 2021-07-21        53500
# 7   Honda   Blue          54738      4   7000 2021-07-22        60500
# 8  Toyota  White          60000      4   6250 2021-07-23        66750
# 9  Nissan  White          31600      4   9700 2021-07-24        76450

# %%
car_sales.plot(x="Sale Date", y="Total Sales")
# Out:
# <AxesSubplot:xlabel='Sale Date'>

# %%
car_sales.plot(x="Sale Date", y ="Total Sales")
# Out:
# <AxesSubplot:xlabel='Sale Date'>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
x = np.random.rand(10, 4)

# %%
x
# Out:
# array([[0.53579948, 0.22640278, 0.03424701, 0.70891995],
#        [0.05956145, 0.87239772, 0.96546189, 0.73362881],
#        [0.15549741, 0.60762061, 0.75155375, 0.58615952],
#        [0.12001916, 0.87365629, 0.22509933, 0.55297404],
#        [0.62214789, 0.72054576, 0.37998471, 0.25681615],
#        [0.71617351, 0.18779055, 0.10299378, 0.57935182],
#        [0.02592902, 0.62131826, 0.22169144, 0.44202724],
#        [0.2376992 , 0.62231613, 0.41587802, 0.57716388],
#        [0.52394086, 0.64692871, 0.21775055, 0.11051104],
#        [0.66779726, 0.42111983, 0.55763758, 0.84521911]])

# %%
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])

# %%
df
# Out:
#           a         b         c         d
# 0  0.535799  0.226403  0.034247  0.708920
# 1  0.059561  0.872398  0.965462  0.733629
# 2  0.155497  0.607621  0.751554  0.586160
# 3  0.120019  0.873656  0.225099  0.552974
# 4  0.622148  0.720546  0.379985  0.256816
# 5  0.716174  0.187791  0.102994  0.579352
# 6  0.025929  0.621318  0.221691  0.442027
# 7  0.237699  0.622316  0.415878  0.577164
# 8  0.523941  0.646929  0.217751  0.110511
# 9  0.667797  0.421120  0.557638  0.845219

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sale Price  Total Sales  \
# 0  Toyota  White         150043      4   4000 2021-07-15         4000
# 1   Honda    Red          87899      4   5000 2021-07-16         9000
# 2  Toyota   Blue          32549      3   7000 2021-07-17        16000
# 3     BMW  Black          11179      5  22000 2021-07-18        38000
# 4  Nissan  White         213095      4   3500 2021-07-19        41500
# 5  Toyota  Green          99213      4   4500 2021-07-20        46000
# 6   Honda   Blue          45698      4   7500 2021-07-21        53500
# 7   Honda   Blue          54738      4   7000 2021-07-22        60500
# 8  Toyota  White          60000      4   6250 2021-07-23        66750
# 9  Nissan  White          31600      4   9700 2021-07-24        76450
#
#    Sale Date
# 0 2021-07-15
# 1 2021-07-16
# 2 2021-07-17
# 3 2021-07-18
# 4 2021-07-19
# 5 2021-07-20
# 6 2021-07-21
# 7 2021-07-22
# 8 2021-07-23
# 9 2021-07-24

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot(figsize=(10, 30), subplots = True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots = True);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease.plot(kind="scatter",
                   x = "age",
                   y ="chol",
                   c = "target",
                   figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
over_50.plot(kind = "scatter",
           x= "age",
           y = "chol",
           c = "target",
           figsize = (10, 6))
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind = "scatter",
            x = "age",
            y = "chol",
            c="target",
            ax=ax);
ax.set_xlim([45, 100]);

# %%
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"],
                    over_50["chol"],
                    c=over_50["target"])

ax.set(title = "Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholestero");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"],
                    over_50["chol"],
                    c=over_50["target"])

ax.set(title = "Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target")

ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %%
fig, (ax0, ax1) = plt.subplots(
                      nrows=2,
                      ncols=1,
                      sharex= True,
                       figsize=(10, 8)
                      )
scatter = ax0.scatter(over_50["age"],
                     over_50["chol"],
                     c= over_50["target"])

ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")
ax0.axhline(y=over_50["chol"].mean(),
           color="b",
           linestyle="--",
           label="average")

scatter = ax1.scatter(over_50["age"],
                     over_50["chol"],
                     c= over_50["target"])

ax1.set(title="Heart Disease and Max Heart Rate Levels",
       xlabel="Age",
       ylabel="Max Heart Rate")

ax1.legend(*scatter.legend_elements(), title="Target")
ax1.axhline(y=over_50["thalach"].mean(),
           color="b",
           linestyle="--",
           label="Average")

fig.suptitle("Heart Disease Analysis",fontsize=16, fontweight="bold");

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Price"].dtype
# Out:
# dtype('int32')

# %%
car_sales["Prices"] = car_sales["Prices"].dropna()

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.dropna(axis="Prices")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 'Prices'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-9b532e4ab0e6> in <module>
# ----> 1 car_sales.dropna(axis="Prices")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4989             raise TypeError("supplying multiple axes to axis is no longer supported.")
#    4990
# -> 4991         axis = self._get_axis_number(axis)
#    4992         agg_axis = 1 - axis
#    4993
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# --> 370             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#     371
#     372     @classmethod
#
# ValueError: No axis named Prices for object type DataFrame

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Prices
# 0  Toyota  White         150043      4   4000    4000
# 1   Honda    Red          87899      4   5000    5000
# 2  Toyota   Blue          32549      3   7000    7000
# 3     BMW  Black          11179      5  22000   22000
# 4  Nissan  White         213095      4   3500    3500
# 5  Toyota  Green          99213      4   4500    4500
# 6   Honda   Blue          45698      4   7500    7500
# 7   Honda   Blue          54738      4   7000    7000
# 8  Toyota  White          60000      4   6250    6250
# 9  Nissan  White          31600      4   9700    9700

# %%
car_sales = car_sales.drop(["Prices"], axis= 1)

# %%
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Prices
# 0  Toyota  White         150043      4   4000    4000
# 1   Honda    Red          87899      4   5000    5000
# 2  Toyota   Blue          32549      3   7000    7000
# 3     BMW  Black          11179      5  22000   22000
# 4  Nissan  White         213095      4   3500    3500
# 5  Toyota  Green          99213      4   4500    4500
# 6   Honda   Blue          45698      4   7500    7500
# 7   Honda   Blue          54738      4   7000    7000
# 8  Toyota  White          60000      4   6250    6250
# 9  Nissan  White          31600      4   9700    9700

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
plt.style.use("seaborn-whitegrid")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y ="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import numpy as np

# %%
x = np.random.randn(10, 4)

# %%
x
# Out:
# array([[ 1.33186087, -0.84628653,  0.3065551 ,  1.9216512 ],
#        [ 0.82139581,  0.85251447, -0.84334779,  0.35837337],
#        [-0.79581575, -1.46520719, -2.41398499, -1.18425044],
#        [ 1.12762237, -0.25861301, -1.10877766, -0.32630203],
#        [-0.50419285,  1.25564327,  0.33850521, -0.60462105],
#        [-0.18206314,  0.48037477, -1.82188215, -0.34703066],
#        [ 1.30162034,  0.47733718, -0.25212069, -0.05128939],
#        [-0.56541351,  0.67576912,  1.53712794, -0.13199841],
#        [-0.37275276, -0.89287171, -0.53129164,  0.96085264],
#        [-0.10938373, -0.37894344, -0.16654462, -0.13864764]])

# %%
df = pd.DataFrame(x, columns =["a", "b", "c", "d"])

# %%
df
# Out:
#           a         b         c         d
# 0  1.331861 -0.846287  0.306555  1.921651
# 1  0.821396  0.852514 -0.843348  0.358373
# 2 -0.795816 -1.465207 -2.413985 -1.184250
# 3  1.127622 -0.258613 -1.108778 -0.326302
# 4 -0.504193  1.255643  0.338505 -0.604621
# 5 -0.182063  0.480375 -1.821882 -0.347031
# 6  1.301620  0.477337 -0.252121 -0.051289
# 7 -0.565414  0.675769  1.537128 -0.131998
# 8 -0.372753 -0.892872 -0.531292  0.960853
# 9 -0.109384 -0.378943 -0.166545 -0.138648

# %%
ax = df.plot(kind="bar")

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax = df.plot(kind="bar")
ax.set(title= "Chocolaty Kinza Amjad is my love", xlabel="Rabia Amjad", ylabel="Ramsha Naseer")
ax.legend().set_visible(True)

# %%
ax = df.plot(kind="bar")
ax.set(title="Chocolaty Kinza Amjad is so so Cute", xlabel="Ramsha Naseer", ylabel="Rabia Amjad")
ax.legend().set_visible(True)

# %%
plt.style.use("seaborn-whitegrid")

# No cmap change
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.axhline(y=over_50["chol"].mean(), 
           c='b', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"], 
                     cmap="winter")
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(), 
           color='r', 
           linestyle='--', 
           label="Average");
ax.legend(*scatter.legend_elements(), title="Target");

# %%
## Before the change (we've had color updates)

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
## After adding in different x & y limitations

fig, (ax0, ax1) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10, 10))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")

# Set the x axis
ax0.set_xlim([50, 80])

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")

# Set the y axis
ax1.set_ylim([60, 200])

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='r', 
            linestyle='--', 
            label="Average");
ax1.legend(*scatter.legend_elements(), title="Target")

# Title the figure
fig.suptitle('Heart Disease Analysis', fontsize=16, fontweight='bold');

# %%
fig.savefig("chocolaty-kinza-amjad.png")
